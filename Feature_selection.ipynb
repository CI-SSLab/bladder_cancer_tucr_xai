# %%
# !pip install jupyter-dash
# !pip install dash-bio==1.0.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: jupyter-dash in /usr/local/lib/python3.7/dist-packages (0.4.2)
# Requirement already satisfied: dash in /usr/local/lib/python3.7/dist-packages (from jupyter-dash) (2.5.1)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.7/dist-packages (from jupyter-dash) (4.10.1)
# Requirement already satisfied: ansi2html in /usr/local/lib/python3.7/dist-packages (from jupyter-dash) (1.7.0)
# Requirement already satisfied: flask in /usr/local/lib/python3.7/dist-packages (from jupyter-dash) (1.1.4)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.7/dist-packages (from jupyter-dash) (1.5.5)
# Requirement already satisfied: retrying in /usr/local/lib/python3.7/dist-packages (from jupyter-dash) (1.3.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from jupyter-dash) (2.23.0)
# Requirement already satisfied: ipython in /usr/local/lib/python3.7/dist-packages (from jupyter-dash) (5.5.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from ansi2html->jupyter-dash) (4.11.4)
# Requirement already satisfied: flask-compress in /usr/local/lib/python3.7/dist-packages (from dash->jupyter-dash) (1.12)
# Requirement already satisfied: dash-html-components==2.0.0 in /usr/local/lib/python3.7/dist-packages (from dash->jupyter-dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /usr/local/lib/python3.7/dist-packages (from dash->jupyter-dash) (5.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /usr/local/lib/python3.7/dist-packages (from dash->jupyter-dash) (2.0.0)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from dash->jupyter-dash) (5.5.0)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from flask->jupyter-dash) (2.11.3)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from flask->jupyter-dash) (7.1.2)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from flask->jupyter-dash) (1.0.1)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from flask->jupyter-dash) (1.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->flask->jupyter-dash) (2.0.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly>=5.0.0->dash->jupyter-dash) (8.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly>=5.0.0->dash->jupyter-dash) (1.15.0)
# Requirement already satisfied: brotli in /usr/local/lib/python3.7/dist-packages (from flask-compress->dash->jupyter-dash) (1.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->ansi2html->jupyter-dash) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->ansi2html->jupyter-dash) (4.1.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel->jupyter-dash) (5.3.5)
# Requirement already satisfied: tornado>=4.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel->jupyter-dash) (5.1.1)
# Requirement already satisfied: traitlets>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel->jupyter-dash) (5.1.1)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython->jupyter-dash) (1.0.18)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython->jupyter-dash) (2.6.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython->jupyter-dash) (0.7.5)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython->jupyter-dash) (4.4.2)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython->jupyter-dash) (0.8.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython->jupyter-dash) (57.4.0)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython->jupyter-dash) (4.8.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->jupyter-dash) (0.2.5)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel->jupyter-dash) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel->jupyter-dash) (4.10.0)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel->jupyter-dash) (23.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->ipython->jupyter-dash) (0.7.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->jupyter-dash) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->jupyter-dash) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->jupyter-dash) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->jupyter-dash) (3.0.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: dash-bio==1.0.1 in /usr/local/lib/python3.7/dist-packages (1.0.1)
# Requirement already satisfied: biopython>=1.77 in /usr/local/lib/python3.7/dist-packages (from dash-bio==1.0.1) (1.79)
# Requirement already satisfied: periodictable in /usr/local/lib/python3.7/dist-packages (from dash-bio==1.0.1) (1.6.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from dash-bio==1.0.1) (2.23.0)
# Requirement already satisfied: scikit-learn>=0.20.1 in /usr/local/lib/python3.7/dist-packages (from dash-bio==1.0.1) (1.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from dash-bio==1.0.1) (1.4.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from dash-bio==1.0.1) (1.3.5)
# Requirement already satisfied: colour in /usr/local/lib/python3.7/dist-packages (from dash-bio==1.0.1) (0.1.5)
# Requirement already satisfied: dash>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from dash-bio==1.0.1) (2.5.1)
# Requirement already satisfied: GEOparse>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from dash-bio==1.0.1) (2.0.3)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from dash-bio==1.0.1) (4.3.3)
# Requirement already satisfied: parmed in /usr/local/lib/python3.7/dist-packages (from dash-bio==1.0.1) (3.4.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from biopython>=1.77->dash-bio==1.0.1) (1.21.6)
# Requirement already satisfied: dash-html-components==2.0.0 in /usr/local/lib/python3.7/dist-packages (from dash>=1.6.1->dash-bio==1.0.1) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /usr/local/lib/python3.7/dist-packages (from dash>=1.6.1->dash-bio==1.0.1) (5.0.0)
# Requirement already satisfied: flask-compress in /usr/local/lib/python3.7/dist-packages (from dash>=1.6.1->dash-bio==1.0.1) (1.12)
# Requirement already satisfied: Flask>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from dash>=1.6.1->dash-bio==1.0.1) (1.1.4)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from dash>=1.6.1->dash-bio==1.0.1) (5.5.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /usr/local/lib/python3.7/dist-packages (from dash>=1.6.1->dash-bio==1.0.1) (2.0.0)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask>=1.0.4->dash>=1.6.1->dash-bio==1.0.1) (1.1.0)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=1.0.4->dash>=1.6.1->dash-bio==1.0.1) (7.1.2)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=1.0.4->dash>=1.6.1->dash-bio==1.0.1) (2.11.3)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask>=1.0.4->dash>=1.6.1->dash-bio==1.0.1) (1.0.1)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.7/dist-packages (from GEOparse>=1.1.0->dash-bio==1.0.1) (4.64.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask>=1.0.4->dash>=1.6.1->dash-bio==1.0.1) (2.0.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->dash-bio==1.0.1) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->dash-bio==1.0.1) (2.8.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly>=5.0.0->dash>=1.6.1->dash-bio==1.0.1) (8.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly>=5.0.0->dash>=1.6.1->dash-bio==1.0.1) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->dash-bio==1.0.1) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->dash-bio==1.0.1) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->dash-bio==1.0.1) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->dash-bio==1.0.1) (3.0.4)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.1->dash-bio==1.0.1) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.1->dash-bio==1.0.1) (3.1.0)
# Requirement already satisfied: brotli in /usr/local/lib/python3.7/dist-packages (from flask-compress->dash>=1.6.1->dash-bio==1.0.1) (1.0.9)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema->dash-bio==1.0.1) (4.11.4)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->dash-bio==1.0.1) (5.7.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from jsonschema->dash-bio==1.0.1) (4.1.1)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->dash-bio==1.0.1) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->dash-bio==1.0.1) (0.18.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources>=1.4.0->jsonschema->dash-bio==1.0.1) (3.8.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from periodictable->dash-bio==1.0.1) (3.0.9)

# %%
import numpy as np
import scipy
import h5py
import pandas as pd
import dash_bio

# %% [markdown]
# ## Load data

# %%
with h5py.File('genes_data.h5', 'r') as fd:
    fd_hg = fd['FD_HG'][:]
    fd_lg = fd['FD_LG'][:]
    fd_n = fd['FD_N'][:]
    fd_label = [x.decode() for x in fd['FD_Labels']]


print(f'FD_HG: {fd_hg.shape}')
print(f'FD_LG: {fd_lg.shape}')
print(f'FD_N: {fd_n.shape}')
# Out:
# FD_HG: (12, 1920)
# FD_LG: (12, 1920)
# FD_N: (17, 1920)

# %% [markdown]
# Define functions

# %%
def preprocess_fd(fd):
    if fd.shape[0] > 1:
        fd = np.mean(fd, axis=0)
    return fd


def fold_change(x, y, use_log=False):
    if use_log:
        x = np.log2(x)
        y = np.log2(y)
    return x - y  # difference of logarithms


def filter_genes(x, gtype):
    if gtype == 'up':
        return

# %% [markdown]
# # Experiments
#
# We choose one of the three experimental settings:
#
# - HG vs N
# - LG vs N
# - (HG $\cup$ LG) vs N

# %% [markdown]
# ## HG vs N

# %%
current_fd = fd_hg
exp_fd = preprocess_fd(fd_hg)
exp_fd_n = preprocess_fd(fd_n)

# %% [markdown]
# ## LG vs L

# %%
current_fd = fd_lg
exp_fd = preprocess_fd(fd_lg)
exp_fd_n = preprocess_fd(fd_n)

# %% [markdown]
# ## (HG $\cup$ LG) vs N

# %%
current_fd = np.concatenate([fd_lg, fd_hg], axis=0)
exp_fd = preprocess_fd(current_fd)
exp_fd_n = preprocess_fd(fd_n)

# %% [markdown]
# Computation to obtain Volcano Plot parameters:
#
# * Log Fold Change
# * p-value by Welch's t-test

# %%
# Compute fold change
log_fold_change = fold_change(exp_fd, exp_fd_n) 

# Calculate the Welch's t-test of two independent samples of scores
fd_n_pv = scipy.stats.ttest_ind(current_fd, fd_n, equal_var=False).pvalue

# %% [markdown]
# Set Fold-Change and volcano plot parameters
#
# * **lfc_thr:** log fold change threshold
# * **pv_thr:** p-value threshold

# %%
lfc = 'expsFC'
pv = 'pv'
fc_value = 2
lfc_thr = (-np.log2(fc_value), np.log2(fc_value))
pv_thr = 0.001

# %% [markdown]
# Produce volcano plot

# %%
df = pd.DataFrame({
    'expsFC': log_fold_change,
    'pv': fd_n_pv,
    'genes_idx': list(range(log_fold_change.shape[0])),
    'genes_label': fd_label
})


dash_bio.VolcanoPlot(dataframe=df, effect_size='expsFC', p='pv', snp='genes_idx',
                     gene='genes_label', effect_size_line=lfc_thr, 
                     genomewideline_value=-np.log10(pv_thr), xlabel='log2(FC)')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="95b7c31c-5eb2-4a6c-b466-fa88d86d38a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
>GENE: uc.325+A","SNP: 830<br>GENE: uc.153+A","SNP: 831<br>GENE: uc.153+A","SNP: 837<br>GENE: uc.177+A","SNP: 840<br>GENE: uc.16+","SNP: 841<br>GENE: uc.16+","SNP: 842<br>GENE: uc.20+","SNP: 843<br>GENE: uc.20+","SNP: 858<br>GENE: uc.89+","SNP: 859<br>GENE: uc.89+","SNP: 880<br>GENE: uc.457+","SNP: 881<br>GENE: uc.457+","SNP: 1008<br>GENE: uc.388+A","SNP: 1009<br>GENE: uc.388+A","SNP: 1011<br>GENE: uc.392+A","SNP: 1014<br>GENE: uc.412+A","SNP: 1015<br>GENE: uc.412+A","SNP: 1054<br>GENE: uc.372+","SNP: 1055<br>GENE: uc.372+","SNP: 1070<br>GENE: uc.248+A","SNP: 1071<br>GENE: uc.248+A","SNP: 1112<br>GENE: uc.44+A","SNP: 1113<br>GENE: uc.44+A","SNP: 1114<br>GENE: uc.48+A","SNP: 1115<br>GENE: uc.48+A","SNP: 1140<br>GENE: uc.448+A","SNP: 1141<br>GENE: uc.448+A","SNP: 1144<br>GENE: uc.456+A","SNP: 1145<br>GENE: uc.456+A","SNP: 1198<br>GENE: uc.288+A","SNP: 1199<br>GENE: uc.288+A","SNP: 1246<br>GENE: uc.468+","SNP: 1247<br>GENE: uc.468+","SNP: 1274<br>GENE: uc.200+","SNP: 1290<br>GENE: uc.268+","SNP: 1291<br>GENE: uc.268+","SNP: 1342<br>GENE: uc.96+","SNP: 1343<br>GENE: uc.96+","SNP: 1346<br>GENE: uc.404+","SNP:  ...

# %% [markdown]
# Filter fold change and return upregulated and downregulated

# %%
# Get up/down regulated
upreg = df.loc[(df[lfc] >= -lfc_thr[0]) & (df[pv] < pv_thr)]
downreg = df.loc[(df[lfc] <= -lfc_thr[1]) & (df[pv] < pv_thr)]

print("Total up/down regulated genes,", upreg.shape[0] + downreg.shape[0])
# Out:
# Total up/down regulated genes, 131

# %% [markdown]
# Filter out duplicated genes retaining most significant fold change based on p-value score

# %%
selected_genes = pd.concat([upreg, downreg]).sort_values(by='pv')

group_sg = selected_genes.groupby('genes_label')

new_genes = pd.DataFrame()

for i, gene in enumerate(group_sg['genes_label']):
    genes = selected_genes.loc[selected_genes['genes_label'] == gene[0]]
    genes = genes.drop_duplicates(subset='genes_label', keep='last')
    new_genes = pd.concat([new_genes, genes], )

new_genes = new_genes.sort_values(by='pv')

print("Filtered genes:", new_genes.shape)
new_genes.head()
# Out:
# Filtered genes: (70, 4)
#        expsFC            pv  genes_idx genes_label
# 242  2.734768  9.549333e-13        242       uc.8+
# 572  1.312917  2.148362e-11        572     uc.369+
# 86   1.318176  2.625789e-11         86     uc.346+
# 68   1.066556  5.321091e-09         68    uc.466+A
# 420 -1.908603  1.036398e-08        420    uc.354+A

# %% [markdown]
# Save output samples

# %%
fd_n_filtered = fd_n[:, new_genes['genes_idx']] 
fd_lg_filtered = fd_lg[:, new_genes['genes_idx']] 
fd_hg_filtered = fd_hg[:, new_genes['genes_idx']] 

x = pd.DataFrame(np.vstack([fd_n_filtered, fd_lg_filtered, fd_hg_filtered]))

y = pd.DataFrame([i for i in range(x.shape[0])])
labels = new_genes.sort_values(by=['genes_idx'])['genes_label']

x.to_csv('X_0001_2.csv')
y.to_csv('Y.csv')
labels.to_csv('Labels_0001_2.csv')
